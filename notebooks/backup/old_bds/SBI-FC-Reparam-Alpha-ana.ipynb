# %% [markdown]
# RUN SBI-SGM in alpha
#
# parameters order is  :taue,taui,tauG,speed,alpha,gii,gei (In second)
#
# **some results**
#
# - The following changes make **little effect** on results (I can not discern whether it is due to randomness or not).
#     - change values on ind_conn in [0, 0.2]
#     - change the number of pts for alpha bands (5, or 20)
#     - change the num of rounds in [2, 4]
#     - change the num of sps from 1000 to 500
#     - addv=0.3 (var is small)
#
# - The following changes make **large effect** on results
#     - change noise sd from 0.2 to (0.1, 0.15, 0.25), (decrease corr a lot)
#     - change num of rounds from 3 to (5, 10) (decrease corr)
#     - change num of sps from 1000 to 2000 (decrease corr)
#     - addv=0.5 decreases corr (around 0.35, but var is small)
#
#
# 11 Nov, 2022
# Now let us stick to following
#
# - num of rounds: 3
#
# - noise sd: 0.2
#
# - addv: 0.05
#
# - num of sps: 1000
#
# Tuning direction:

# %% [markdown]
# ## Import some pkgs

# %%
import sys
sys.path.append("../mypkg")

import scipy
import itertools

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import trange
from scipy.io import loadmat
from functools import partial
from easydict import EasyDict as edict
# Out:
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# SBI and torch
from sbi.inference.base import infer
from sbi.inference import SNPE, prepare_for_sbi, simulate_for_sbi
from sbi import analysis
from sbi.utils.get_nn_models import posterior_nn
from sbi import utils as sutils

import torch.nn as nn
import torch.nn.functional as F
import torch
from torch.distributions.multivariate_normal import MultivariateNormal

# %%
# my own fns
from brain import Brain
from FC_utils import build_fc_freq_m
from constants import RES_ROOT, DATA_ROOT
from utils.misc import load_pkl, save_pkl
from utils.reparam import theta_raw_2out, logistic_np, logistic_torch

# %% [markdown]
# ## Some fns

# %%
def _simulate_data(raw_params, brain, prior_bds, freqrange):
    params = []
    for raw_param, prior_bd in zip(raw_params, prior_bds):
        param =  _map_fn_torch(raw_param)*(prior_bd[1]-prior_bd[0]) + prior_bd[0]
        params.append(param)
    params = torch.tensor(params)
    
    params_dict = dict()
    params_dict["tau_e"] =  params[0].item()
    params_dict["tau_i"] =  params[1].item()
    params_dict["tauC"] =  params[2].item()
    params_dict["speed"] =  params[3].item()
    params_dict["alpha"] =  params[4].item()
    params_dict["gii"] =  params[5].item()
    params_dict["gei"] =  params[6].item()
    modelFC = build_fc_freq_m(brain , params_dict, freqrange)
    return np.abs(modelFC[:68, :68])

# %%
_minmax_vec = lambda x: (x-np.min(x))/(np.max(x)-np.min(x))

# %%
# transfer vec to a sym mat
def _vec_2mat(vec):
    mat = np.zeros((68, 68))
    mat[np.triu_indices(68, k = 1)] = vec
    mat = mat + mat.T
    return mat

# %%
# paras to model FC via sgm
def _paras_2FC(raw_params, brain, prior_bds, freqrange):
    params = []
    for raw_param, prior_bd in zip(raw_params, prior_bds):
        param =  _map_fn_torch(raw_param)*(prior_bd[1]-prior_bd[0]) + prior_bd[0]
        params.append(param)
    params = torch.tensor(params)
    
    params_dict = dict()
    params_dict["tau_e"] =  params[0].item()
    params_dict["tau_i"] =  params[1].item()
    params_dict["tauC"] =  params[2].item()
    params_dict["speed"] =  params[3].item()
    params_dict["alpha"] =  params[4].item()
    params_dict["gii"] =  params[5].item()
    params_dict["gei"] =  params[6].item()
    modelFC = build_fc_freq_m(brain , params_dict, freqrange)
    return modelFC[:68, :68]
    
#taue,taui,tauG,speed,alpha,gii,gei

# %%
def get_mode(x):
    kde_est = scipy.stats.gaussian_kde(x)
    xs = np.linspace(x.min(), x.max(), 500)
    ys = kde_est(xs)
    return xs[np.argmax(ys)]

# %% [markdown]
# ### Some parameters

# %%
_paras = edict()
_paras.delta = [2, 3.5]
_paras.theta = [4, 7]
_paras.alpha = [8, 12]
_paras.beta = [13, 20]

# %%
# Parameter bounds for optimization
v_lower = 3.5-1.8
v_upper = 3.5+1.8
bnds = ((0.005,0.030), (0.005,0.2), (0.005,0.030), (v_lower,v_upper), (0.1,1.0), (0.5,10.0), (0.5,10.0))
#taue,taui,tauG,speed,alpha,gii,gei

# %%
paras = edict()

paras.fc_type = "alpha" #stick to coh
paras.freqrange =  np.linspace(_paras[paras.fc_type][0], _paras[paras.fc_type][1], 5)
print(paras.freqrange)
paras.fs = 600
paras.num_nodes = 86 # Number of cortical (68) + subcortical nodes
paras.par_low =  np.array([ix[0] for ix in bnds])
paras.par_high = np.array([ix[1] for ix in bnds])
paras.prior_bds = np.array([paras.par_low, paras.par_high]).T
paras.prior_sd = 10
paras.add_v = 0.05

paras.SBI_paras = edict()
paras.SBI_paras.num_prior_sps = int(1e3)
paras.SBI_paras.density_model = "nsf"
paras.SBI_paras.num_round = 3
paras.SBI_paras.noise_sd = 0.20
paras.SBI_paras.save_dir =  f"posteriorMRmul_{paras.fc_type}_" + \
                            f"num{paras.SBI_paras.num_prior_sps}_" + \
                            f"density{paras.SBI_paras.density_model}_" + \
                            f"MR{paras.SBI_paras.num_round}_" + \
                            f"noise_sd{paras.SBI_paras.noise_sd*100:.0f}_" +\
                            f"addv{paras.add_v*100:.0f}"
print(paras.SBI_paras.save_dir, (RES_ROOT/paras.SBI_paras.save_dir).exists())
# Out:
# [ 8.  9. 10. 11. 12.]
# posteriorMRmul_alpha_num1000_densitynsf_MR3_noise_sd20_addv5 True

# %%
# fn for reparemetering
_map_fn_torch = partial(logistic_torch, k=0.1)
_theta_raw_2out = partial(theta_raw_2out, map_fn=partial(logistic_np, k=0.1))

# %%
prior = MultivariateNormal(loc=torch.zeros(7), covariance_matrix=torch.eye(7)*(paras.prior_sd**2))

# %% [markdown]
# ### Load the data

# %%
# SC
ind_conn_xr = xr.open_dataarray('../data/individual_connectomes_reordered.nc')
ind_conn = ind_conn_xr.values

# PSD
ind_psd_xr = xr.open_dataarray('../data/individual_psd_reordered_matlab.nc')
ind_psd = ind_psd_xr.values
fvec = ind_psd_xr["frequencies"].values

# %%
def _add_v2con(cur_ind_conn):
    cur_ind_conn = cur_ind_conn.copy()
    add_v = np.max(cur_ind_conn)*paras.add_v # tuning 0.1
    np.fill_diagonal(cur_ind_conn[:34, 34:68], cur_ind_conn[:34, 34:68] + add_v)
    np.fill_diagonal(cur_ind_conn[34:68, :34], cur_ind_conn[34:68, :34] + add_v)
    np.fill_diagonal(cur_ind_conn[68:77, 77:], cur_ind_conn[68:77, 77:] + add_v)
    np.fill_diagonal(cur_ind_conn[77:, 68:77], cur_ind_conn[77:, 68:77] + add_v)
    return cur_ind_conn


if paras.add_v != 0:
    print(f"Add {paras.add_v} on diag")
    ind_conn_adds = [_add_v2con(ind_conn[:, :, ix]) for ix in range(36)]
    ind_conn = np.transpose(np.array(ind_conn_adds), (1, 2, 0))
# Out:
# Add 0.05 on diag

# %%
# Load true MEG FC time series:
dataPath = DATA_ROOT/f'./MEG_FC_{paras.fc_type}_DK_networks_coh.mat'
data = loadmat(dataPath);
true_FC = data[f"MEG_{paras.fc_type}_FC_networks_coh"]
true_FC.shape
# Out:
# (68, 68, 36)

# %% [markdown]
# ## Analyze the results for single data

# %%
res_fils = list((RES_ROOT/paras.SBI_paras.save_dir).glob("*.pkl"))
_sorted_fn = lambda x: int(x.stem.split("ind")[-1][:])
sorted_fils = sorted(res_fils, key=_sorted_fn)

# %% [markdown]
# ### Point est

# %%
cur_idx = 22
cur_posterior = load_pkl(sorted_fils[cur_idx])
post_sps = cur_posterior.sample((10000, ))
# Out:
# Load file /data/rajlab1/user_data/jin/MyResearch/SBI-SGM-FC1/SBI-SGM-FC/notebooks/../mypkg/../results/posteriorMRmul_alpha_num1000_densitynsf_MR3_noise_sd15_addv5/ind22.pkl
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
cur_est_paras = torch.median(post_sps, axis=0)[0]
    
# get the cur brain
brain = Brain.Brain()
brain.add_connectome(DATA_ROOT) # grabs distance matrix
brain.reorder_connectome(brain.connectome, brain.distance_matrix)
brain.connectome =  ind_conn[:, :, cur_idx] # re-assign connectome to individual connectome
brain.bi_symmetric_c()
brain.reduce_extreme_dir()
    
cur_obs_FC = np.abs(true_FC[:, :, cur_idx])
cur_est_FC = np.abs(_paras_2FC(cur_est_paras, 
                               brain=brain, 
                               prior_bds=paras.prior_bds, 
                               freqrange=paras.freqrange))
est_vec = _minmax_vec(cur_est_FC[np.triu_indices(68, k = 1)])
obs_vec = _minmax_vec(cur_obs_FC[np.triu_indices(68, k = 1)])
corr = scipy.stats.pearsonr(est_vec, obs_vec)[0]

# %%
SC = brain.connectome[:68, :68]
SC_vec = _minmax_vec(SC[np.triu_indices(68, k = 1)])
est_FC_mm = _vec_2mat(est_vec)
obs_FC_mm = _vec_2mat(obs_vec)
SC_mm = _vec_2mat(SC_vec)

plt.figure(figsize=[18, 5])
plt.subplot(132)
plt.title(f"SGM FC (corr: {corr:.3f})")
sns.heatmap(est_FC_mm)
plt.subplot(133)
plt.title("Empirical FC")
sns.heatmap(obs_FC_mm)
#sns.heatmap(cur_obs_FC)
plt.subplot(131)
plt.title("SC")
sns.heatmap(SC_mm)
# Out:
# <AxesSubplot:title={'center':'SC'}>

# %% [markdown]
# ### Full Bayesian

# %%
cur_idx = 11
# get the cur brain
brain = Brain.Brain()
brain.add_connectome(DATA_ROOT) # grabs distance matrix
brain.reorder_connectome(brain.connectome, brain.distance_matrix)
brain.connectome =  ind_conn[:, :, cur_idx] # re-assign connectome to individual connectome
brain.bi_symmetric_c()
brain.reduce_extreme_dir()

_simulate_data_sp = partial(_simulate_data, 
                            brain=brain, 
                            prior_bds=paras.prior_bds, 
                            freqrange=paras.freqrange)
_simulate_data_wrapper, _ = prepare_for_sbi(_simulate_data_sp, prior)

# %%
cur_posterior = load_pkl(sorted_fils[cur_idx])

_, cur_post_psds = simulate_for_sbi(_simulate_data_wrapper, cur_posterior,
                                    num_simulations=100, 
                                    num_workers=20)
cur_post_psds = cur_post_psds.reshape(-1, 68, 68)
# Out:
# Load file /data/rajlab1/user_data/jin/MyResearch/SBI-SGM-FC1/SBI-SGM-FC/notebooks/../mypkg/../results/posteriorMRmul_num2000_densitynsf_MR3_noise_sd20/ind11.pkl
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)
# /home/hujin/.local/lib/python3.9/site-packages/sbi/utils/user_input_checks.py:499: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:250.)
#   return torch.as_tensor(simulator(theta), dtype=float32)

# %%
cur_obs_FC = np.abs(true_FC[:, :, cur_idx])
cur_est_FC = np.abs(cur_post_psds.mean(axis=0).numpy())
est_vec = _minmax_vec(cur_est_FC[np.triu_indices(68, k = 1)])
obs_vec = _minmax_vec(cur_obs_FC[np.triu_indices(68, k = 1)])
corr = scipy.stats.pearsonr(est_vec, obs_vec)[0]

# %%
SC = brain.connectome[:68, :68]
SC_vec = _minmax_vec(SC[np.triu_indices(68, k = 1)])
est_FC_mm = _vec_2mat(est_vec)
obs_FC_mm = _vec_2mat(obs_vec)
SC_mm = _vec_2mat(SC_vec)

plt.figure(figsize=[18, 5])
plt.subplot(132)
plt.title(f"SGM FC (corr: {corr:.3f})")
sns.heatmap(est_FC_mm)
plt.subplot(133)
plt.title("Empirical FC")
sns.heatmap(obs_FC_mm)
#sns.heatmap(cur_obs_FC)
plt.subplot(131)
plt.title("SC")
sns.heatmap(SC_mm)
# Out:
# <AxesSubplot:title={'center':'SC'}>

# %% [markdown]
# ## All data analysis

# %%
res_fils = list((RES_ROOT/paras.SBI_paras.save_dir).glob("*.pkl"))
_sorted_fn = lambda x: int(x.stem.split("ind")[-1][:])
sorted_fils = sorted(res_fils, key=_sorted_fn)

# %% [markdown]
# ### Point est

# %%
inf_res = edict()
inf_res.est_FCs = []

corrs = []
for cur_idx in range(36):
    cur_posterior = load_pkl(sorted_fils[cur_idx], False)
    post_sps = cur_posterior.sample((1000, ))
    cur_est_paras = torch.median(post_sps, axis=0)[0]
        
    # get the cur brain
    brain = Brain.Brain()
    brain.add_connectome(DATA_ROOT) # grabs distance matrix
    brain.reorder_connectome(brain.connectome, brain.distance_matrix)
    brain.connectome =  ind_conn[:, :, cur_idx] # re-assign connectome to individual connectome
    brain.bi_symmetric_c()
    brain.reduce_extreme_dir()
        
    cur_obs_FC = np.abs(true_FC[:, :, cur_idx])
    cur_est_FC = np.abs(_paras_2FC(cur_est_paras, 
                                   brain=brain, 
                                   prior_bds=paras.prior_bds, 
                                   freqrange=paras.freqrange))
    est_vec = _minmax_vec(cur_est_FC[np.triu_indices(68, k = 1)])
    obs_vec = _minmax_vec(cur_obs_FC[np.triu_indices(68, k = 1)])
    corr = scipy.stats.pearsonr(est_vec, obs_vec)[0]
    corrs.append(corr)
    inf_res.est_FCs.append(cur_est_FC)
inf_res.corrs = corrs
save_pkl(sorted_fils[0].parent/"inf_res.pkl", inf_res, True)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Save to /data/rajlab1/user_data/jin/MyResearch/SBI-SGM-FC1/SBI-SGM-FC/notebooks/../mypkg/../results/posteriorMRmul_alpha_num1000_densitynsf_MR3_noise_sd20_addv5/inf_res.pkl

# %%
# [10000, 1000], 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.381(0.006)')

# %% [markdown]
# #### Past results

# %%
# [10000, 1000], 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.363(0.012)')

# %%
# 1000, 3, 0.3
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.370(0.003)')

# %%
# 500, 3, 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.373(0.007)')

# %%
# 1000, 3, 0.20
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.366(0.003)')

# %%
# 1000, 3, 0.05, 20pts for bands
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.378(0.009)')

# %%
# 1000, 4, 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.365(0.011)')

# %%
# 1000, 3, 0.10
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.370(0.007)')

# %%
# 1000, 3, 0.07
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.365(0.011)')

# %%
# 1000, 3, 0.05 r1
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.380(0.006)')

# %%
# 1000, 3, 0.05 r2
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.364(0.011)')

# %%
# 1000, 3, 0.05 r3
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.381(0.006)')

# %%
# 1000, 3, 0.0
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs)
plt.plot(corrs, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.367(0.005)')

# %% [markdown]
# ### Full Bayesian

# %%
inf_res_fb = edict()
inf_res_fb.est_FCs = []

corrs_fb = []
for cur_idx in range(36):
# get the cur brain
    brain = Brain.Brain()
    brain.add_connectome(DATA_ROOT) # grabs distance matrix
    brain.reorder_connectome(brain.connectome, brain.distance_matrix)
    brain.connectome =  ind_conn[:, :, cur_idx] # re-assign connectome to individual connectome
    brain.bi_symmetric_c()
    brain.reduce_extreme_dir()
    
    _simulate_data_sp = partial(_simulate_data, 
                                brain=brain, 
                                prior_bds=paras.prior_bds, 
                                freqrange=paras.freqrange)
    _simulate_data_wrapper, _ = prepare_for_sbi(_simulate_data_sp, prior)
    
    cur_posterior = load_pkl(sorted_fils[cur_idx], False)
    _, cur_post_psds = simulate_for_sbi(_simulate_data_wrapper, cur_posterior,
                                        num_simulations=1000, 
                                        num_workers=50)
    cur_post_psds = cur_post_psds.reshape(-1, 68, 68)
    
    cur_obs_FC = np.abs(true_FC[:, :, cur_idx])
    cur_est_FC = np.abs(cur_post_psds.mean(axis=0).numpy())
    est_vec = _minmax_vec(cur_est_FC[np.triu_indices(68, k = 1)])
    obs_vec = _minmax_vec(cur_obs_FC[np.triu_indices(68, k = 1)])
    corr = scipy.stats.pearsonr(est_vec, obs_vec)[0]
    corrs_fb.append(corr)
    inf_res_fb.est_FCs.append(cur_est_FC)
    
inf_res_fb.corrs = corrs_fb
save_pkl(sorted_fils[0].parent/"inf_res_fb.pkl", inf_res_fb)
# Out:
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# /data/rajlab1/user_data/jin/MyResearch/SBI-SGM-FC1/SBI-SGM-FC/notebooks/../mypkg/../results/posteriorMRmul_alpha_num1000_densitynsf_MR3_noise_sd20_addv5/inf_res_fb.pkl exists! Use is_force=True to save it anyway

# %%
# 1000, 3, 0.30
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.375(0.004)')

# %% [markdown]
# #### Past results

# %%
# 1000, 3, 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.363(0.007)')

# %%
# 1000, 3, 0.30
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.364(0.003)')

# %%
# 500, 3, 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.372(0.004)')

# %%
# 1000, 3, 0.20
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.363(0.003)')

# %%
# 1000, 3, 0.05, 20 pts
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.371(0.007)')

# %%
# 1000, 4, 0.05
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.367(0.005)')

# %%
# 1000, 3, 0.10
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.370(0.004)')

# %%
# 1000, 3, 0.07
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.376(0.005)')

# %%
# 1000, 3, 0.05 r1
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.375(0.004)')

# %%
# 1000, 3, 0.05 r2
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.364(0.007)')

# %%
# 1000, 3, 0.05, r3
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.373(0.004)')

# %%
# 1000, 3, 0.0
plt.figure(figsize=[20, 5])
mcorr=np.mean(corrs_fb)
plt.plot(corrs_fb, "o-r")
plt.title(f"Alpha {mcorr:.3f}({np.var(corrs_fb):.3f})", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Alpha 0.368(0.004)')
